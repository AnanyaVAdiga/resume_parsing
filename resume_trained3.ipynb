# %%
import os
from llama_index.core import SimpleDirectoryReader
import pandas as pd
import json
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from transformers import pipeline, AutoTokenizer, AutoModelForTokenClassification

# Load Hugging Face models for classification and NER
def load_classification_pipeline(model_name):
    return pipeline("zero-shot-classification", model=model_name)

def load_ner_pipeline(model_name):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForTokenClassification.from_pretrained(model_name)
    return pipeline("ner", model=model, tokenizer=tokenizer)

# Define model names and initialize pipelines
classification_model_name = "facebook/bart-large-mnli"  # Replace with your preferred classification model
classifier = load_classification_pipeline(classification_model_name)

ner_model_name = "dbmdz/bert-large-cased-finetuned-conll03-english"  # Replace with your preferred NER model
ner_pipeline = load_ner_pipeline(ner_model_name)

# Function to get text from files using llama_index
def extract_text_with_llama(file_dir):
    try:
        reader = SimpleDirectoryReader(file_dir)
        documents = reader.load_data()  # Extracts and combines all text from files
        return "\n".join([doc.text for doc in documents])
    except Exception as e:
        print(f"Error processing files in directory {file_dir}: {e}")
        return None

# Function to classify text into dynamic categories
def classify_text(text, categories):
    result = classifier(text, candidate_labels=categories)
    return result['labels'][0], result['scores'][0]  # return top label and score

# Function to extract named entities based on dynamic labels
def extract_entities(text, entity_labels):
    entities = ner_pipeline(text)
    return [(ent['word'], ent['entity']) for ent in entities if ent['entity'] in entity_labels]

# Function to annotate text based on dynamic categories and entities
def annotate_text(text, categories, entity_labels):
    category, confidence = classify_text(text, categories)
    entities = extract_entities(text, entity_labels)
    return {
        "category": category,
        "confidence": confidence,
        "entities": entities
    }

# Function to dynamically extract skills (can be improved with pre-defined skill lists)
def extract_skills(text):
    # Use a TF-IDF Vectorizer to identify potential skills from the text
    vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1, 2))
    tfidf_matrix = vectorizer.fit_transform([text])
    feature_names = vectorizer.get_feature_names_out()
    scores = tfidf_matrix.sum(axis=0).A1
    skills = [feature_names[i] for i in scores.argsort()[::-1] if scores[i] > 0.1]  # threshold can be adjusted
    return skills

# Function to parse a single resume
def parse_resume(file_dir, categories, entity_labels):
    text = extract_text_with_llama(file_dir)
    if not text:
        print(f"Failed to extract text from {file_dir}")
        return None

    # Extract relevant information
    skills = extract_skills(text)

    # Dynamically annotate the text based on categories and entities
    annotations = annotate_text(text, categories, entity_labels)

    # Parse results
    return {
        "text": text,
        "skills": ", ".join(skills) if skills else None,
        "annotations": annotations
    }

# Function to load and parse all resumes in a directory
def load_resumes(directory, categories, entity_labels):
    resumes = []
    for filename in os.listdir(directory):
        if filename.endswith(('.pdf', '.docx', '.doc')):
            file_path = os.path.join(directory, filename)
            print(f"Processing file: {file_path}")
            parsed_resume = parse_resume(file_path, categories, entity_labels)
            if parsed_resume:
                resumes.append(parsed_resume)
    return resumes

# Function to match resumes with job descriptions using TF-IDF and cosine similarity
def match_resume_with_jd(resume_text, job_description):
    documents = [resume_text, job_description]
    tfidf = TfidfVectorizer().fit_transform(documents)
    similarity_matrix = cosine_similarity(tfidf[0:1], tfidf[1:2])
    return similarity_matrix[0][0]  # Return the similarity score

# Function to segregate files by job descriptions
def segregate_files_by_jd(resumes, job_descriptions, base_directory):
    if not os.path.exists(base_directory):
        os.makedirs(base_directory)

    for resume in resumes:
        highest_match = 0
        best_jd = None
        
        for jd_title, jd_text in job_descriptions.items():
            match_score = match_resume_with_jd(resume['text'], jd_text)
            if match_score > highest_match:
                highest_match = match_score
                best_jd = jd_title

        if best_jd:
            jd_directory = os.path.join(base_directory, best_jd)
            if not os.path.exists(jd_directory):
                os.makedirs(jd_directory)

            # Sanitize the resume name to avoid illegal characters
            resume_filename = f"resume_{resumes.index(resume)}.txt"
            file_path = os.path.join(jd_directory, resume_filename)

            try:
                with open(file_path, 'w', encoding='utf-8') as file:
                    file.write(resume['text'])
                print(f"Moved resume {resumes.index(resume)} to {jd_directory}")
            except Exception as e:
                print(f"Error writing file {file_path}: {e}")

# Main execution
if __name__ == "__main__":
    # Define paths and job descriptions
    directory = "C:\\Users\\ananya\\Desktop\\RR\\resumes"  # Directory containing resumes
    base_directory = "C:\\Users\\ananya\\Desktop\\RR\\Results"  # Directory to save categorized resumes
    job_descriptions = {
        "AI engineer": "The AI Engineer designs and implements artificial intelligence models and algorithms...",
        "Business development executive": "The Business Development Executive is responsible for identifying...",
        "Subject matter expert": "The Subject Matter Expert provides expert knowledge and insights..."
    }
    
    categories = ["education", "skill", "experience", "interest", "personal information"]
    entity_labels = ["PER", "ORG", "LOC", "MISC"]  # Adjust according to the NER model used
    
    resumes = load_resumes(directory, categories, entity_labels)
    segregate_files_by_jd(resumes, job_descriptions, base_directory)
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Processing file: C:\Users\ananya\Desktop\RR\resumes\1707727659390_Gudi Madhu Latha-CV.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\1707727659390_Gudi Madhu Latha-CV.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\1707727659390_Gudi Madhu Latha-CV.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\1707727659390_Gudi Madhu Latha-CV.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Aakash_Muthreja_CV1 (1).pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Aakash_Muthreja_CV1 (1).pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Aakash_Muthreja_CV1 (1).pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Aakash_Muthreja_CV1 (1).pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Aakash_Muthreja_CV1.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Aakash_Muthreja_CV1.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Aakash_Muthreja_CV1.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Aakash_Muthreja_CV1.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Ajay _Resume_2024_PM.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Ajay _Resume_2024_PM.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Ajay _Resume_2024_PM.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Ajay _Resume_2024_PM.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\ALOK NATH (1).pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\ALOK NATH (1).pdf: Directory C:\Users\ananya\Desktop\RR\resumes\ALOK NATH (1).pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\ALOK NATH (1).pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Aswathi p_Mcc (4).pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Aswathi p_Mcc (4).pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Aswathi p_Mcc (4).pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Aswathi p_Mcc (4).pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Atul Narayan.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Atul Narayan.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Atul Narayan.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Atul Narayan.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Avkash-Resume.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Avkash-Resume.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Avkash-Resume.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Avkash-Resume.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Brototi Banerjee_Final_CV_Updated (2).docx
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Brototi Banerjee_Final_CV_Updated (2).docx: Directory C:\Users\ananya\Desktop\RR\resumes\Brototi Banerjee_Final_CV_Updated (2).docx does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Brototi Banerjee_Final_CV_Updated (2).docx
# Processing file: C:\Users\ananya\Desktop\RR\resumes\CURRICULUM VITAE.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\CURRICULUM VITAE.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\CURRICULUM VITAE.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\CURRICULUM VITAE.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\cvnd24 (3).pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\cvnd24 (3).pdf: Directory C:\Users\ananya\Desktop\RR\resumes\cvnd24 (3).pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\cvnd24 (3).pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\CV_2023070509122292.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\CV_2023070509122292.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\CV_2023070509122292.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\CV_2023070509122292.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\CV_Resume.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\CV_Resume.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\CV_Resume.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\CV_Resume.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\CV_Sudheer Kumar Puvvula_Latest.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\CV_Sudheer Kumar Puvvula_Latest.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\CV_Sudheer Kumar Puvvula_Latest.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\CV_Sudheer Kumar Puvvula_Latest.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\DHANYA 1 (1).docx
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\DHANYA 1 (1).docx: Directory C:\Users\ananya\Desktop\RR\resumes\DHANYA 1 (1).docx does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\DHANYA 1 (1).docx
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Dhruthi R.docx
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Dhruthi R.docx: Directory C:\Users\ananya\Desktop\RR\resumes\Dhruthi R.docx does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Dhruthi R.docx
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Digital Marketing Resume Himanshu (1).pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Digital Marketing Resume Himanshu (1).pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Digital Marketing Resume Himanshu (1).pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Digital Marketing Resume Himanshu (1).pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\DOC-20230803-WA0013 (7).docx
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\DOC-20230803-WA0013 (7).docx: Directory C:\Users\ananya\Desktop\RR\resumes\DOC-20230803-WA0013 (7).docx does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\DOC-20230803-WA0013 (7).docx
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Gopika_Gopan_Resume_2024.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Gopika_Gopan_Resume_2024.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Gopika_Gopan_Resume_2024.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Gopika_Gopan_Resume_2024.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Hansa cv.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Hansa cv.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Hansa cv.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Hansa cv.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Hari Kunjeti -Resume (1)-converted (1) (2) (1).docx
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Hari Kunjeti -Resume (1)-converted (1) (2) (1).docx: Directory C:\Users\ananya\Desktop\RR\resumes\Hari Kunjeti -Resume (1)-converted (1) (2) (1).docx does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Hari Kunjeti -Resume (1)-converted (1) (2) (1).docx
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Himanshu Resume.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Himanshu Resume.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Himanshu Resume.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Himanshu Resume.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Kumaraswamy-Designer-070524.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Kumaraswamy-Designer-070524.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Kumaraswamy-Designer-070524.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Kumaraswamy-Designer-070524.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\ManeshSreedharResume (1).pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\ManeshSreedharResume (1).pdf: Directory C:\Users\ananya\Desktop\RR\resumes\ManeshSreedharResume (1).pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\ManeshSreedharResume (1).pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\MANIKANTHA POOJARI .pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\MANIKANTHA POOJARI .pdf: Directory C:\Users\ananya\Desktop\RR\resumes\MANIKANTHA POOJARI .pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\MANIKANTHA POOJARI .pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Michelraj J_Resume (1).pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Michelraj J_Resume (1).pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Michelraj J_Resume (1).pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Michelraj J_Resume (1).pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Mohamed ashik (1).pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Mohamed ashik (1).pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Mohamed ashik (1).pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Mohamed ashik (1).pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\MY CV Soubhik (2).pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\MY CV Soubhik (2).pdf: Directory C:\Users\ananya\Desktop\RR\resumes\MY CV Soubhik (2).pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\MY CV Soubhik (2).pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\MY CV Yashaswini.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\MY CV Yashaswini.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\MY CV Yashaswini.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\MY CV Yashaswini.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\N Gautham Bhat CV-2.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\N Gautham Bhat CV-2.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\N Gautham Bhat CV-2.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\N Gautham Bhat CV-2.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\pdf&rendition=1 (1).pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\pdf&rendition=1 (1).pdf: Directory C:\Users\ananya\Desktop\RR\resumes\pdf&rendition=1 (1).pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\pdf&rendition=1 (1).pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Priyam Ray Updated Resume - New (1) (2).pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Priyam Ray Updated Resume - New (1) (2).pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Priyam Ray Updated Resume - New (1) (2).pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Priyam Ray Updated Resume - New (1) (2).pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Ragu (1).pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Ragu (1).pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Ragu (1).pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Ragu (1).pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\reaume self.docx
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\reaume self.docx: Directory C:\Users\ananya\Desktop\RR\resumes\reaume self.docx does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\reaume self.docx
# Processing file: C:\Users\ananya\Desktop\RR\resumes\RESUME NAZHATH FATHIMA_101505 (1).doc
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\RESUME NAZHATH FATHIMA_101505 (1).doc: Directory C:\Users\ananya\Desktop\RR\resumes\RESUME NAZHATH FATHIMA_101505 (1).doc does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\RESUME NAZHATH FATHIMA_101505 (1).doc
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Resume.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Resume.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Resume.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Resume.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\resume2 (1).pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\resume2 (1).pdf: Directory C:\Users\ananya\Desktop\RR\resumes\resume2 (1).pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\resume2 (1).pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Sagar M - Work resume.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Sagar M - Work resume.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Sagar M - Work resume.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Sagar M - Work resume.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Share Praful wasekar 2021 update resume-1 (1).pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Share Praful wasekar 2021 update resume-1 (1).pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Share Praful wasekar 2021 update resume-1 (1).pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Share Praful wasekar 2021 update resume-1 (1).pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Srresume 1.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Srresume 1.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Srresume 1.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Srresume 1.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Subhankar Chakraborty Resume.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Subhankar Chakraborty Resume.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Subhankar Chakraborty Resume.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Subhankar Chakraborty Resume.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\SubhankarMohantyResume .pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\SubhankarMohantyResume .pdf: Directory C:\Users\ananya\Desktop\RR\resumes\SubhankarMohantyResume .pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\SubhankarMohantyResume .pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\SushanthB Resume 1.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\SushanthB Resume 1.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\SushanthB Resume 1.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\SushanthB Resume 1.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\TANISHA GHOSH..docx.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\TANISHA GHOSH..docx.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\TANISHA GHOSH..docx.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\TANISHA GHOSH..docx.pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Thejeswini_Resume_6_Yrs_Exp (1).docx
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Thejeswini_Resume_6_Yrs_Exp (1).docx: Directory C:\Users\ananya\Desktop\RR\resumes\Thejeswini_Resume_6_Yrs_Exp (1).docx does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Thejeswini_Resume_6_Yrs_Exp (1).docx
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Vineesh-1 (1).pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Vineesh-1 (1).pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Vineesh-1 (1).pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Vineesh-1 (1).pdf
# Processing file: C:\Users\ananya\Desktop\RR\resumes\Yashaswini Resume.pdf
# Error processing files in directory C:\Users\ananya\Desktop\RR\resumes\Yashaswini Resume.pdf: Directory C:\Users\ananya\Desktop\RR\resumes\Yashaswini Resume.pdf does not exist.
# Failed to extract text from C:\Users\ananya\Desktop\RR\resumes\Yashaswini Resume.pdf
